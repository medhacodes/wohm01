# %%
import pandas as pd 


import seaborn as sns 

import matplotlib.pyplot as plt 


df = pd.read_csv("Book2.csv",encoding = "unicode_escape")

# %%
df.head(15)
# Out:
#     Unnamed: 0 LOWER COND TEMP AT INELT' LOWER COND TEMP AT OUTLET  \
# 1          NaN                     33.99                     30.02
# 2          NaN                     34.29                        31
# 3          NaN                     34.11                     31.92
# 4          NaN                     33.75                     31.16
# 5          NaN                     33.12                     30.58
# 6          NaN                     33.16                     29.41
# 7          NaN                     33.75                      31.2
# 8          NaN                      33.2                     29.29
# 9          NaN                     33.16                      29.7
# 10         NaN                     33.29                     30.08
# 11         NaN                     35.08                      32.2
# 12         NaN                      33.2                     30.37
# 13         NaN                        33                        30
# ...

# %%
df.sample(10)
# Out:
#       Unnamed: 0 LOWER COND TEMP AT INELT' LOWER COND TEMP AT OUTLET  \
# 278          NaN                   By pass                   By pass
# 249          NaN                       NaN                       NaN
# 647          NaN                     32.25                     30.54
# 405          NaN                     29.69                     27.45
# 641          NaN                     31.33                     29.87
# 751          NaN                     31.46                     29.54
# 829          NaN                      31.7                     29.94
# 695          NaN                      30.8                     28.81
# 1125         NaN                     31.86                      30.2
# 344          NaN                   By pass                   By pass
#
#      UPPER COND TEMPE AT INELT UPPER COND TEMPE AT OUTLET  \
# 278                    By pass                    By pass
# 249                        NaN                        NaN
# ...

# %%
df.head()
# Out:
#    Unnamed: 0 LOWER COND TEMP AT INELT' LOWER COND TEMP AT OUTLET  \
# 1         NaN                     33.99                     30.02
# 2         NaN                     34.29                        31
# 3         NaN                     34.11                     31.92
# 4         NaN                     33.75                     31.16
# 5         NaN                     33.12                     30.58
#
#   UPPER COND TEMPE AT INELT UPPER COND TEMPE AT OUTLET  \
# 1                     27.36                      22.18
# 2                     27.66                      22.75
# 3                     26.67                      22.81
# 4                      28.5                      23.54
# 5                     28.87                      23.25
#
#   BENZOL WASHER INLET GAS TEMP BENZOL WASHER  OUTLET GAS TEMP  \
# 1                        27.58                          35.97
# 2                        27.39                          36.58
# ...

# %%
df.isnull().sum()
# Out:
# Unnamed: 0                    1224
# LOWER COND TEMP AT INELT'      149
# LOWER COND TEMP AT OUTLET      149
# UPPER COND TEMPE AT INELT      149
# UPPER COND TEMPE AT OUTLET     148
#                               ...
# Unnamed: 206                  1187
# Unnamed: 207                  1187
# Unnamed: 208                  1187
# Unnamed: 209                  1187
# Unnamed: 210                  1187
# Length: 211, dtype: int64

# %%
df.shape
# Out:
# (1224, 211)

# %%
df.unique()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_21952/41981628.py in <module>
# ----> 1 df.unique
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5485         ):
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#    5488
#    5489     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'unique'
