# %%
import time 

import pandas as pd

import numpy as np

df = pd.read_csv("2nd.csv",encoding = "unicode_escape")

# %%
df.head(39)
# Out:
#    parameters PCT INLET GAS TEMP PCT OUTLET GAS TEMP FGC INLET GAS TEMP  \
# 0        unit                 °C                  °C                 °C
# 1           0                 SD                  SD              42.66
# 2           0                 SD                  SD              42.89
# 3           0                 SD                  SD              40.44
# 4           0                 SD                  SD              41.21
# 5           0                 SD                  SD                 40
# 6           0                 SD                  SD               38.2
# 7           0                 SD                  SD               38.9
# 8           0                 SD                  SD              37.05
# 9           0                 SD                  SD              38.39
# 10          0                 SD                  SD              40.06
# 11          0                 SD                  SD              39.87
# ...

# %%
df.dropna(inplace = True)

# %%
df.head()
# Out:
# Empty DataFrame
# ...
